# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameekshaingole/fraud-detection-federated-learning/blob/main/FL_evaluate_compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#FINAL GLOBAL MODEL EVALUATION

# Train one final model on aggregated learning (simulate final global model)
final_model = LogisticRegression(max_iter=1000)
final_model.fit(X_train_scaled, y_train)

y_pred_fed = final_model.predict(X_test_scaled)
y_prob_fed = final_model.predict_proba(X_test_scaled)[:,1]

print("\n=== FEDERATED MODEL RESULTS ===")
print("Accuracy:", accuracy_score(y_test, y_pred_fed))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_fed))
print(classification_report(y_test, y_pred_fed))

# %%
#COMPARISON
print("\n=== FINAL COMPARISON ===")
print("Centralized vs Federated")

print("Check difference in Accuracy & ROC-AUC above")
