# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameekshaingole/fraud-detection-federated-learning/blob/main/Baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#client banks
import numpy as np

X1, X2, X3 = np.array_split(X, 3)
y1, y2, y3 = np.array_split(y, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_203/3943434888.py in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 X1, X2, X3 = np.array_split(X, 3)
#       4 y1, y2, y3 = np.array_split(y, 3)
#
# NameError: name 'X' is not defined

# %%
#model creation
from tensorflow import keras

def create_model():
    model = keras.Sequential([
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# # New Section
